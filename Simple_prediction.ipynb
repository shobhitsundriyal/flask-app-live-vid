# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
#from keras.applications.imagenet_utils import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
from keras.models import load_model
model = load_model('garbage_mobile224x224.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Vicky\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Vicky\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
classes = ['garbage', 'non_garbage']

# %%
from keras.applications.mobilenet import preprocess_input

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# ...

# %%
im = load_img('validation/garbage/4.jpg', target_size=(224, 224))
print(type(im)
x = img_to_array(im)
print (x.shape)
plt.imshow(x/255.)
x = np.expand_dims(x, axis=0)
print (x.shape)
x = preprocess_input(x)
print('Input image shape:', x.shape)
# Out:
#   File "<ipython-input-12-b5ffa2b92f1a>", line 3
#     x = img_to_array(im)
#     ^
# SyntaxError: invalid syntax

# %%
#x = x.reshape(1,224,224,3)
y_prob = model.predict(x) 
y_classes = y_prob.argmax(axis=-1)
classes[y_classes[0]]
# Out:
# ---------------------------------------------------------------------------
# AbortedError                              Traceback (most recent call last)
# <ipython-input-10-f4dd0b6d9d3d> in <module>
#       1 #x = x.reshape(1,224,224,3)
# ----> 2 y_prob = model.predict(x)
#       3 y_classes = y_prob.argmax(axis=-1)
#       4 classes[y_classes[0]]
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
# ...

# %%
im = load_img('validation/garbage/6.jpg', target_size=(300, 300))

x = img_to_array(im)
plt.imshow(x/255.)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y_prob = model.predict(x) 
y_classes = y_prob.argmax(axis=-1)
classes[y_classes[0]]
# Out:
# 'garbage'

# %%
im = load_img('validation/garbage/ng1.jpg', target_size=(300, 300))

x = img_to_array(im)
plt.imshow(x/255.)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y_prob = model.predict(x) 
y_classes = y_prob.argmax(axis=-1)
classes[y_classes[0]]
# Out:
# 'garbage'

# %%
im = load_img('validation/garbage/ng2.jpg', target_size=(300, 300))

x = img_to_array(im)
plt.imshow(x/255.)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y_prob = model.predict(x) 
y_classes = y_prob.argmax(axis=-1)
classes[y_classes[0]]
# Out:
# 'non_garbage'

# %%
im = load_img('validation/garbage/ng1.jpg', target_size=(300, 300))

x = img_to_array(im)
plt.imshow(x/255.)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y_prob = model.predict(x) 
y_classes = y_prob.argmax(axis=-1)
classes[y_classes[0]]

# %%
from datetime import datetime
now = datetime.now()

# %%
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
dt_string
# Out:
# '29/08/2019 17:54:10'
